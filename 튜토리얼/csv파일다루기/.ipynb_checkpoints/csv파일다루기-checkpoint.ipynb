# %%
import pandas as pd
import random

# %%
# 행수가 10000개이고 컬럼수가 2개인 데이터를 아무렇게나 만들어서 저장해볼게요!
몇개 = 10_000
random.seed(1)
df = pd.DataFrame({'col_1':range(몇개),'col_2':[random.randint(1,10000) for _ in range(몇개)]})

#저장!
df.to_csv(f'{몇개}.csv',index=False)

# %%
df #데이터는 이렇게생겼습니다!
# Out:
#       col_1  col_2
# 0         0   2202
# 1         1   9326
# 2         2   1034
# 3         3   4180
# 4         4   1932
# ...     ...    ...
# 9995   9995   8967
# 9996   9996    508
# 9997   9997   7413
# 9998   9998   3992
# 9999   9999   6954
#
# [10000 rows x 2 columns]

# %%
# 저장한 파일을 읽어와볼게요 
import time 

시작시점 = time.time()

#읽어오기!
읽어봐 = pd.read_csv(f'{몇개}.csv') 
끝시점 = time.time()
print(f'읽는시간 : {끝시점 - 시작시점:.2f}초')
# Out:
# 읽는시간 : 0.21 초

# %%
몇개 = 100_000
random.seed(1)
df = pd.DataFrame({'col_1':range(몇개),'col_2':[random.randint(1,10000) for _ in range(몇개)]})

df.to_csv(f'{몇개}.csv',index=False) #저장!

시작시점 = time.time()
읽어봐 = pd.read_csv(f'{몇개}.csv') #읽어오기!
끝시점 = time.time()
print(f'읽는시간 : {끝시점 - 시작시점:.2f}초')
# Out:
# 읽는시간 : 0.04초

# %%
몇개 = 1_000_000
random.seed(1)
df = pd.DataFrame({'col_1':range(몇개),'col_2':[random.randint(1,10000) for _ in range(몇개)]})

df.to_csv(f'{몇개}.csv',index=False) #저장!

시작시점= time.time()
읽어봐 = pd.read_csv(f'{몇개}.csv') #읽어오기!
끝시점= time.time()
print(f'읽는시간 : {끝시점 - 시작시점:.2f}초')
# Out:
# 읽는시간 : 0.24초

# %% [markdown]
# 100만줄의 csv 파일을 <span style='background-color:lightblue'> 엑셀에서</span> 읽는 것과 <br>
# <span style='background-color:lightblue'> 파이썬에서</span> 읽는 것, 무엇이 훨씬 빠를까요?

# %%
# 천만줄은 엑셀 프로그램으로 열수도 없네요ㅠ

몇개 = 10_000_000
random.seed(1)
df = pd.DataFrame({'col_1':range(몇개),'col_2':[random.randint(1,10000) for _ in range(몇개)]})

df.to_csv(f'{몇개}.csv',index=False) #저장!

시작시점= time.time()
읽어봐 = pd.read_csv(f'{몇개}.csv') #읽어오기!
끝시점= time.time()
print(f'읽는시간 : {끝시점 - 시작시점:.2f}초')
# Out:
# 읽는시간 : 2.22초

# %% [markdown]
# <span style='background-color:yellow'>관전 포인트1 </span> : 파이썬에서 100만줄의 csv 파일을 읽는 것은 0.5초도 안걸린다. (그럼 엑셀은?)   <br>
# <span style='background-color:yellow'>관전 포인트2 </span>  : 엑셀프로그램은 용량이 큰 파일은 열수도 없다. (최대 1,048,576 행)

# %% [markdown]
#  우리는 보통 천만줄의 모든 데이터가 필요하지 않습니다.<br>
# 주로 특정 조건에 해당하는 데이터만 관심있을 때가 많죠.<br>
# 천만줄의 csv파일에서 <span style='background-color:orange'> col_2 열 값이 149인 경우만</span> 필요하다고 가정하겠습니다.

# %% [markdown]
# 실제 지금 필요한 데이터는 약 천줄이 채 안되는 데도, 일단 파일 전체를 읽었어야만 합니다.<br>
# 전체 데이터를 읽는데에는 2.2초가 걸렸었습니다.<br>
# 데이터를 조회할때마다 그 만큼의 <span style='color:red; font-weight:bold'>시간을 비용으로 지불</span>하는 꼴이지요!<br>
# 시간만 지불 했을까요? 천만줄의 데이터를 모두 PC RAM(메모리) 공간에 올려놓았기 때문에<span style='color:red; font-weight:bold'> 메모리의 비용</span>도 들었습니다.

# %%
읽어봐.query("col_2==149")
# Out:
#            col_1  col_2
# 22585      22585    149
# 32645      32645    149
# 48010      48010    149
# 92671      92671    149
# 100477    100477    149
# ...          ...    ...
# 9958947  9958947    149
# 9960106  9960106    149
# 9984708  9984708    149
# 9990526  9990526    149
# 9992445  9992445    149
#
# [955 rows x 2 columns]

# %% [markdown]
# 굳이 전체 파일을 확인하지 않고 149값의 행만 가져오는 방법은 무엇일까요? <br>
#
# 단 하나의 방법 밖에 없을 것 같은데요.<br>
# 바로!  <span style='background-color:yellow'>col_2 열의 값 별로 파일을 따로 따로 저장</span>해놓는 것입니다..
#
# 우리가 다루는 데이터마다, 컬럼값 별로 파일을 매번 쪼개놓아야 한다면 얼마나 귀찮을까요?<br>
# 이 귀찮을걸 <span style='background-color:yellow; color:red; font-size:20px; font-weight:bold;text-decoration: green wavy underline;'>데이터베이스!!</span>가 알아서 해줍니다.<span style="color:blue">(장점1)</span> <br>
#
# 똑같은 데이터를 .csv 파일이 아니라 데이터베이스에서 읽어보겠습니다. <br>
# (미리 데이터베이스를 설치하고, 데이터를 sample이라는 테이블로 저장해놓았습니다.)

# %% [markdown]
# 데이터베이스의 <span style="color:blue">(장점2)</span>는 데이터를 공유하기 위해 이메일, 메신저로 파일을 보내주지 않고 <br>
# 몇 줄의 명령어로 가져올 수있다는 것입니다.

# %%
# from sqlalchemy import create_engine

# engine = create_engine('mysql+pymysql://root:1234@localhost:3306/junsik') #DB서버 연결 

# 시작시점 = time.time()
# 읽어봐.to_sql(name='sample', con=engine, chunksize=10000,if_exists='replace',index=False) 
# 끝시점 = time.time()
# print('db적재시간 :', 끝시점 - 시작시점)
# Out:
# db적재시간 : 190.91976737976074

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:1234@localhost:3306/junsik') #DB서버 연결 

#쿼리작성 
query = '''
select *
from sample
where col_2 = 149
'''

시작시점 = time.time()
읽어봐_DB = pd.read_sql(query, con=engine) #조회
끝시점 = time.time()
print(f'읽는시간 : {끝시점 - 시작시점:.2f}초')
# Out:
# 읽는시간 : 0.03194451332092285

# %% [markdown]
# <span style='background-color:orange'> col_2 값이 149인 데이터</span>를 조회하는데에 0.05초도 안걸리네요 !

# %%
읽어봐_DB
# Out:
#        col_1  col_2
# 0      22585    149
# 1      32645    149
# 2      48010    149
# 3      92671    149
# 4     100477    149
# ..       ...    ...
# 950  9958947    149
# 951  9960106    149
# 952  9984708    149
# 953  9990526    149
# 954  9992445    149
#
# [955 rows x 2 columns]

# %% [markdown]
# 기존 csv 파일에서 149에 해당하는 데이터를 뽑기위해선 전체데이터를 읽었어야 했지만,<br>
# Database에서는 col_2값 기준으로 폴더가 나뉘어있기 때문에 시간과 메모리를 절약했습니다.<br>
# 절약 효과는, 필요한 데이터양 대비 전체 데이터 규모가 클수록 더 많아지겠네요!

# %%
import pyodbc

mydb = pyodbc.connect(
    driver="{MYSQL ODBC 8.4 Unicode Driver}",
    server="localhost",
    uid="root",
    pwd="1234",
    database="junsik") 
cur = mydb.cursor()

# %%
def select_all(): #조회 함수생성
    
    cur = mydb.cursor()                     #커서 객체생성
    sql ='''SELECT * FROM test'''     #조회 SQL

    cur.execute(sql)                        #커서를 통한 SQL실행
    select_all_result = cur.fetchall()      #커서의 결과를 담는 객체

    for x in select_all_result:
        print(x)

select_all()                                #함수 실행
# Out:
# (18, 'aaa')
# (19, 'aasd')
# (20, 'aasd')
# (21, 'aasd')

# %%
my_uid = "root"
my_pwd = "1234"
my_host = "localhost"
my_db = "junsik"
my_odbc_driver = "MYSQL ODBC 8.4 Unicode Driver"

connection_uri = sa.engine.url.URL.create(
"mssql+pyodbc",
username=my_uid,
password=my_pwd,
host=my_host,
database=my_db,  # required; not an empty string
query={"driver": my_odbc_driver},
)
print(connection_uri)
e = sa.create_engine(connection_uri, fast_executemany=True)
# Out:
# mssql+pyodbc://root:***@localhost/junsik?driver=MYSQL+ODBC+8.4+Unicode+Driver

# %%
@event.listens_for(e, 'before_cursor_execute')
def receive_before_cursor_execute(conn, cursor, statement, params, context, executemany):
    if executemany:
        cursor.fast_executemany = True
        cursor.commit()
        

시작시점 = time.time()
읽어봐.loc[:100000].to_sql(name='sample', con=e, chunksize=10000,if_exists='replace')
끝시점 = time.time()
print('db적재시간 :', 끝시점 - 시작시점)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\base.py:1960, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1959     if not evt_handled:
# -> 1960         self.dialect.do_execute(
#    1961             cursor, str_statement, effective_parameters, context
#    1962         )
#    1964 if self._has_events or self.engine._has_events:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\sqlalchemy\engine\default.py:924, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     923 def do_execute(self, cursor, statement, parameters, context=None):
# --> 924     cursor.execute(statement, parameters)
#
# ...

# %%
q = '''
select *
from sample
'''

시작시점 = time.time()
읽어봐_DB = pd.read_sql(con=engine)
끝시점 = time.time()
print('읽는시간 :', 끝시점 - 시작시점)
